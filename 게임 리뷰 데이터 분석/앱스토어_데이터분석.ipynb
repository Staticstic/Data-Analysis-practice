# %% [markdown]
# <a href="https://colab.research.google.com/github/Staticstic/Data-Analysis-practice/blob/main/%EC%95%B1%EC%8A%A4%ED%86%A0%EC%96%B4_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 앱 스토어 데이터 분석
# ***

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
#AppleGothic (한글 글씨체 나눔고딕 다운로드)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt
plt.rc('font',family="NanumBarunGothic")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# ▶ 경로 설정 (※ Colab을 활성화시켰다면 보통 Colab Notebooks 폴더가 자동 생성)
import os
os.chdir("/content/drive/MyDrive/bytedegree")
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/bytedegree'

# %%
game_all = pd.read_csv("game_all_20230404.csv")

# %% [markdown]
# # 데이터 전체 확인
# ***

# %%
#행과열을 확인
game_all.shape
# Out:
# (7834, 7)

# %%
#데이터 정보 확인
game_all.info()

# 숫자 : int / float (소숫점 형태)
# 문자 : object (string)
# 날짜 : datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7834 entries, 0 to 7833
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   USER    7834 non-null   object
#  1   DATE    7834 non-null   object
#  2   STAR    7834 non-null   int64
#  3   LIKE    7834 non-null   int64
#  4   TITLE   7834 non-null   object
#  5   REVIEW  7834 non-null   object
#  6   GAME    7834 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 428.5+ KB

# %%
game_all.head()
# Out:
#         USER                       DATE  STAR  LIKE  \
# 0       아아거록  2023-04-02 10:08:55-07:00     5     0
# 1        조가리  2023-03-28 22:19:48-07:00     5     0
# 2     와구와구왕왕  2023-03-27 16:09:04-07:00     5     0
# 3  너너머유낳오토쥬옽  2023-03-27 05:01:02-07:00     4     0
# 4       아랄러로  2023-03-26 06:32:46-07:00     1     0
#
#                        TITLE  \
# 0                         ㄴㄴ
# 1         초보와 고수가 함께하는 화목한게임
# 2            갑자기 렉이 너무 심해졌어요
# 3                     넘 어려워요
# 4  아이폰 14프로 맨날 튕긴다구요!!!!!!!!
#
#                                               REVIEW    GAME
# 0                                               ㄷㅈㄷㅇ  가디언테일즈
# 1  경쟁을 부추기지 않는 게임이라 가능한 분위기\n길드 만들었는데 고수님들 들어와주셔서...  가디언테일즈
# 2  다른 게임은 그대로인데 이번 업뎃에서 끊김현상부터 렉이 어마어마하네요 렉땜에 자꾸 ...  가디언테일즈
# 3                 지금 월드 12에서 막혀서 부활을 계속하는데도 안깨져요 ㅠㅠㅠ  가디언테일즈
# 4  아니!!!!! 맨날 들어갈때마다 튕긴다구요 퓨ㅠㅠㅠㅠㅠ\n거울균열 돌다 튕겨 카마존...  가디언테일즈

# %%
game_all.describe(include="object")
# Out:
#         USER                       DATE TITLE REVIEW    GAME
# count   7834                       7834  7834   7834    7834
# unique  7694                       7829  6447   7400      16
# top     마타도르  2023-03-29 16:02:19-07:00     굿      굿  가디언테일즈
# freq       3                          2   140     76     500

# %%
game_all.GAME.value_counts()
# Out:
# 가디언테일즈      500
# 달빛조각사       500
# 블루아카이브      500
# 배틀그라운드      500
# 탕탕특공대       500
# 바람의나라연      500
# 검은사막        500
# 오딘발할라라이징    500
# 아키에이지워      500
# 미르          500
# 쿠키런킹덤       500
# 리니지m        500
# 리니지w        500
# 원신          500
# 우마무스메       500
# 프라시아전기      334
# Name: GAME, dtype: int64

# %% [markdown]
# # 파생변수
# ***

# %%
game_all['GAME'].unique()
# Out:
# array(['가디언테일즈', '달빛조각사', '블루아카이브', '배틀그라운드', '탕탕특공대', '바람의나라연', '프라시아전기',
#        '검은사막', '오딘발할라라이징', '아키에이지워', '미르', '쿠키런킹덤', '리니지m', '리니지w', '원신',
#        '우마무스메'], dtype=object)

# %%
# 게임 별 유통 회사 변수 생성

def company(x):
    if x in ('가디언테일즈', '달빛조각사', '오딘발할라라이징', '아키에이지워', '우마무스메'):
      return '카카오게임즈'
    elif x in ('블루아카이브', '바람의나라연', '프라시아전기'):
      return '넥슨'
    elif x in ('리니지m', '리니지w'):
      return '엔씨소프트'
    elif x == '검은사막':
      return '펄어비스'
    elif x == '배틀그라운드':
      return '크래프톤'
    elif x == '미르':
      return '위메이드'
    elif x == '쿠키런킹덤':
      return '데브시스터즈'
    elif x == '탕탕특공대':
      return 'Habby'
    elif x == '원신':
      return 'HoYoverse'

game_all['COMPANY']=game_all['GAME'].apply(company)

# %%
# 게임 별 제목 수 , 리뷰 수 파생 변수 생성
game_all["제목수"]=game_all.TITLE.apply(lambda x:len(x))
game_all["리뷰수"]=game_all.REVIEW.apply(lambda x:len(x))
game_all["닉네임수"]=game_all.USER.apply(lambda x:len(x))

# %%
game_all
# Out:
#             USER                       DATE  STAR  LIKE  \
# 0           아아거록  2023-04-02 10:08:55-07:00     5     0
# 1            조가리  2023-03-28 22:19:48-07:00     5     0
# 2         와구와구왕왕  2023-03-27 16:09:04-07:00     5     0
# 3      너너머유낳오토쥬옽  2023-03-27 05:01:02-07:00     4     0
# 4           아랄러로  2023-03-26 06:32:46-07:00     1     0
# ...          ...                        ...   ...   ...
# 7829    말딸 왜함 ㅋㅋ  2022-09-01 18:37:35-07:00     2     0
# 7830        리우메이  2022-09-01 18:36:22-07:00     1     0
# 7831  NeoBlueice  2022-09-01 18:09:01-07:00     1     0
# 7832  @@#8282828  2022-09-01 17:21:51-07:00     1     0
# 7833       m2who  2022-09-01 13:35:37-07:00     1     0
#
#                           TITLE  \
# 0                            ㄴㄴ
# 1            초보와 고수가 함께하는 화목한게임
# 2               갑자기 렉이 너무 심해졌어요
# 3                        넘 어려워요
# 4     아이폰 14프로 맨날 튕긴다구요!!!!!!!!
# ...                         ...
# 7829                        ㅋㅋㅋ
# 7830                       ㅋㅋㅋㅋ
# 7831                  이런 운영은 처음
# 7832                운영 제대로좀 팅긴다
# 7833                       5700
#
#                                                  REVIEW    GAME COMPANY  제목수  \
# 0                                                  ㄷㅈㄷㅇ  가디언테일즈  카카오게임즈    2
# 1     경쟁을 부추기지 않는 게임이라 가능한 분위기\n길드 만들었는데 고수님들 들어와주셔서...  가디언테일즈  카카오게임즈   18
# 2     다른 게임은 그대로인데 이번 업뎃에서 끊김현상부터 렉이 어마어마하네요 렉땜에 자꾸 ...  가디언테일즈  카카오게임즈   15
# 3                    지금 월드 12에서 막혀서 부활을 계속하는데도 안깨져요 ㅠㅠㅠ  가디언테일즈  카카오게임즈    6
# 4     아니!!!!! 맨날 들어갈때마다 튕긴다구요 퓨ㅠㅠㅠㅠㅠ\n거울균열 돌다 튕겨 카마존...  가디언테일즈  카카오게임즈   25
# ...                                                 ...     ...     ...  ...
# 7829                                            ㅋㅋㅋㅋ 안함   우마무스메  카카오게임즈    3
# 7830                                             불탄다 불타   우마무스메  카카오게임즈    4
# 7831  몰래 공지를 수정하지 않나, 유저들이 제발 운영 좀 정상적으로 해달라는 요구에 안 ...   우마무스메  카카오게임즈    9
# 7832                팅긴다고!! 운영 제대로 좀 해라 계속 팅기는데 업데이트 안해줌   우마무스메  카카오게임즈   11
# 7833                                               ㅋㅋㅋㅋ   우마무스메  카카오게임즈    4
#
#       리뷰수  닉네임수
# 0       4     4
# 1      74     3
# 2      60     6
# 3      34     9
# 4     218     4
# ...   ...   ...
# 7829    7     8
# 7830    6     4
# 7831   60    10
# 7832   35    10
# 7833    4     5
#
# [7834 rows x 11 columns]

# %%
# game_all["DATE"]=pd.to_datetime(game_all["DATE"])
game_all["DATE"]=pd.to_datetime(game_all["DATE"])

# %%
#object 형식이였던 데이터를 변경할 수 있음
game_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7834 entries, 0 to 7833
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   USER     7834 non-null   object
#  1   DATE     7834 non-null   datetime64[ns, pytz.FixedOffset(-420)]
#  2   STAR     7834 non-null   int64
#  3   LIKE     7834 non-null   int64
#  4   TITLE    7834 non-null   object
#  5   REVIEW   7834 non-null   object
#  6   GAME     7834 non-null   object
#  7   COMPANY  7834 non-null   object
#  8   제목수      7834 non-null   int64
#  9   리뷰수      7834 non-null   int64
#  10  닉네임수     7834 non-null   int64
# dtypes: datetime64[ns, pytz.FixedOffset(-420)](1), int64(5), object(5)
# memory usage: 673.4+ KB

# %%
#파생변수 생성 (데이터 추출)
game_all["month"]=game_all["DATE"].dt.month
game_all["day"]=game_all["DATE"].dt.day
game_all["hour"]=game_all["DATE"].dt.hour
game_all["minute"]=game_all["DATE"].dt.minute
# 0:월 ~ 6:일
game_all["day_name"]=game_all['DATE'].dt.weekday

# %%
# 요일 한글로 적용하는 법
weekday_list=['월', '화', '수', '목', '금', '토', '일']
game_all['요일']=game_all.apply(lambda x: weekday_list[x['day_name']], axis=1)

# %%
game_all.head()
# Out:
#         USER                      DATE  STAR  LIKE                      TITLE  \
# 0       아아거록 2023-04-02 10:08:55-07:00     5     0                         ㄴㄴ
# 1        조가리 2023-03-28 22:19:48-07:00     5     0         초보와 고수가 함께하는 화목한게임
# 2     와구와구왕왕 2023-03-27 16:09:04-07:00     5     0            갑자기 렉이 너무 심해졌어요
# 3  너너머유낳오토쥬옽 2023-03-27 05:01:02-07:00     4     0                     넘 어려워요
# 4       아랄러로 2023-03-26 06:32:46-07:00     1     0  아이폰 14프로 맨날 튕긴다구요!!!!!!!!
#
#                                               REVIEW    GAME COMPANY  제목수  \
# 0                                               ㄷㅈㄷㅇ  가디언테일즈  카카오게임즈    2
# 1  경쟁을 부추기지 않는 게임이라 가능한 분위기\n길드 만들었는데 고수님들 들어와주셔서...  가디언테일즈  카카오게임즈   18
# 2  다른 게임은 그대로인데 이번 업뎃에서 끊김현상부터 렉이 어마어마하네요 렉땜에 자꾸 ...  가디언테일즈  카카오게임즈   15
# 3                 지금 월드 12에서 막혀서 부활을 계속하는데도 안깨져요 ㅠㅠㅠ  가디언테일즈  카카오게임즈    6
# 4  아니!!!!! 맨날 들어갈때마다 튕긴다구요 퓨ㅠㅠㅠㅠㅠ\n거울균열 돌다 튕겨 카마존...  가디언테일즈  카카오게임즈   25
#
#    리뷰수  닉네임수  month  day  hour  minute  day_name 요일
# 0    4     4      4    2    10       8         6  일
# 1   74     3      3   28    22      19         1  화
# 2   60     6      3   27    16       9         0  월
# 3   34     9      3   27     5       1         0  월
# 4  218     4      3   26     6      32         6  일

# %%
#그냥 하면 인코딩이 안되어있어서 한글도 알파벳으로 나올 수 있기 때문에 encode를 필수적으로 진행해야된다.

#lambda(x : (결과1) if (조건) else (결과2))

game_all["nickname_alpha"]=game_all.USER.apply(lambda x: "alpha" if x.encode().isalpha() else "not")

# %%
#- 전체 글자 별 제목 비율
game_all["all_text_data_length"]=game_all["제목수"]+game_all["리뷰수"]

# %% [markdown]
# # 전체 게임 데이터 분석
# ***

# %%
#게임 별 게임사 분포 확인
game_all.groupby('COMPANY')['GAME'].nunique().to_frame().reset_index()
# Out:
#      COMPANY  GAME
# 0      Habby     1
# 1  HoYoverse     1
# 2         넥슨     3
# 3     데브시스터즈     1
# 4      엔씨소프트     2
# 5       위메이드     1
# 6     카카오게임즈     5
# 7       크래프톤     1
# 8       펄어비스     1

# %%
#게임사별 게임들의 리뷰 평균 구하기
company_star=game_all.groupby('COMPANY')['STAR'].mean().to_frame().reset_index()
company_star
# Out:
#      COMPANY      STAR
# 0      Habby  3.518000
# 1  HoYoverse  4.248000
# 2         넥슨  2.643928
# 3     데브시스터즈  3.570000
# 4      엔씨소프트  1.837000
# 5       위메이드  2.200000
# 6     카카오게임즈  3.123200
# 7       크래프톤  2.750000
# 8       펄어비스  4.490000

# %%
plt.figure(figsize=(8, 5))
c_p=sns.barplot(x="COMPANY", y="STAR", data=company_star,  palette='YlGnBu')
c_p.set_xlabel("게임사", fontsize = 12)
c_p.set_ylabel("평점", fontsize = 12)
# Out:
# Text(0, 0.5, '평점')

# %%
game_star=game_all.groupby('GAME')['STAR'].mean().to_frame().reset_index()
game_star
# Out:
#         GAME      STAR
# 0     가디언테일즈  3.342000
# 1       검은사막  4.490000
# 2      달빛조각사  3.478000
# 3       리니지m  1.828000
# 4       리니지w  1.846000
# 5         미르  2.200000
# 6     바람의나라연  1.878000
# 7     배틀그라운드  2.750000
# 8     블루아카이브  3.358000
# 9     아키에이지워  3.462000
# 10  오딘발할라라이징  3.320000
# 11     우마무스메  2.014000
# 12        원신  4.248000
# 13     쿠키런킹덤  3.570000
# 14     탕탕특공대  3.518000
# 15    프라시아전기  2.721557

# %%
plt.figure(figsize=(12, 8))
plt.xticks(rotation=45)
g_p=sns.barplot(x="GAME", y="STAR", data=game_star,  palette='YlGnBu')
g_p.set_xlabel("게임명", fontsize = 12)
g_p.set_ylabel("평점", fontsize = 12)
# Out:
# Text(0, 0.5, '평점')

# %%
# round(숫자,자릿수) : 자릿수 까지 남기고 다음 자릿수에서 반올림한다.

# {0} , {1} .format(1,2)
# %s : 문자 %d :정수 %f : 실수 , %(값)

print("전체 게임 평균 평점 {0}".format(round(game_all["STAR"].mean(),2)))
print("전체 게임 평균 평점 %f "%(round(game_all["STAR"].mean(),2)))
# Out:
# 전체 게임 평균 평점 3.01
# 전체 게임 평균 평점 3.010000

# %%
#len(game_all[game_all["LIKE"]>0]) : like수가 0 초과인 애들에 대한 수
#len(game_all) : 행의 수


print("전체 좋아요를 받은 전체 댓글 비율 {0}%".format(round(len(game_all[game_all["LIKE"]>0])/len(game_all)*100,2)))
# Out:
# 전체 좋아요를 받은 전체 댓글 비율 2.71%

# %%
game_all[game_all["LIKE"]>0].GAME.value_counts()
# Out:
# 쿠키런킹덤       44
# 원신          42
# 미르          28
# 가디언테일즈      17
# 블루아카이브      14
# 리니지m        12
# 우마무스메       11
# 달빛조각사        9
# 배틀그라운드       8
# 바람의나라연       8
# 리니지w         7
# 탕탕특공대        5
# 검은사막         4
# 오딘발할라라이징     2
# 프라시아전기       1
# Name: GAME, dtype: int64

# %% [markdown]
# ## 좋아요가 있는 데이터 확인

# %% [markdown]
# ## 데이터의 상관관계 확인
# ***

# %%
game_corr=game_all.corr()

# %%
plt.figure(figsize=(16, 10))
heatmap = sns.heatmap(game_all.corr(), vmin=-1, vmax=1, annot=True)

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);


#plotly -> 시각화 패키지 -> 한글 호환

# %% [markdown]
# ## 긍정 데이터 / 부정 데이터 비율 확인

# %%
game_all.groupby('COMPANY')['STAR'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%  max
# COMPANY
# Habby       500.0  3.518000  1.745787  1.0  1.0  5.0  5.0  5.0
# HoYoverse   500.0  4.248000  1.398000  1.0  4.0  5.0  5.0  5.0
# 넥슨         1334.0  2.643928  1.787232  1.0  1.0  2.0  5.0  5.0
# 데브시스터즈      500.0  3.570000  1.585600  1.0  2.0  4.0  5.0  5.0
# 엔씨소프트      1000.0  1.837000  1.508876  1.0  1.0  1.0  2.0  5.0
# 위메이드        500.0  2.200000  1.695213  1.0  1.0  1.0  4.0  5.0
# 카카오게임즈     2500.0  3.123200  1.874200  1.0  1.0  4.0  5.0  5.0
# 크래프톤        500.0  2.750000  1.739411  1.0  1.0  2.0  5.0  5.0
# 펄어비스        500.0  4.490000  1.129802  1.0  5.0  5.0  5.0  5.0

# %%
positive_review=game_all[game_all["STAR"]>3]
negative_review=game_all[game_all["STAR"]<=3]

# %%
len(positive_review)
# Out:
# 3721

# %%
len(negative_review)
# Out:
# 4113

# %%
game_all["STAR_posneg"]=game_all.STAR.apply(lambda x: "pos" if x>3 else "neg")

# %%
positive_review.mean()
# Out:
# STAR                     4.860521
# LIKE                     0.041655
# 제목수                      8.188659
# 리뷰수                     58.146466
# 닉네임수                     5.971513
# month                    4.933889
# day                     17.190809
# hour                    10.817522
# minute                  29.312282
# day_name                 2.793066
# all_text_data_length    66.335125
# dtype: float64

# %%
negative_review.mean()
# Out:
# STAR                     1.330902
# LIKE                     0.038172
# 제목수                     10.742281
# 리뷰수                     66.265257
# 닉네임수                     6.096280
# month                    5.801848
# day                     16.465840
# hour                    10.877948
# minute                  29.465111
# day_name                 2.903963
# all_text_data_length    77.007537
# dtype: float64

# %%
plt.figure(figsize=(8,10))
sns.boxplot(y = "리뷰수", x="STAR_posneg",data =game_all)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x= "제목수", y="STAR_posneg",data =game_all)
plt.savefig('temp.jpg')
plt.show()

# %% [markdown]
# # 시간 별 데이터 분석
# ***

# %%
def data_groupby_time(column_name):
  data_all=game_all.groupby(column_name).count().reset_index()[[column_name,"TITLE"]]
  return data_all

# %%
day_table=data_groupby_time("day")
month_table=data_groupby_time("month")
hour_table=data_groupby_time("hour")
minute_table=data_groupby_time("minute")

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="day", y="TITLE",data=day_table)
# Out:
# <Axes: xlabel='day', ylabel='TITLE'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="month", y="TITLE",data=month_table)
# Out:
# <Axes: xlabel='month', ylabel='TITLE'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="hour", y="TITLE",data=hour_table)
# Out:
# <Axes: xlabel='hour', ylabel='TITLE'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="minute", y="TITLE",data=minute_table)
# Out:
# <Axes: xlabel='minute', ylabel='TITLE'>

# %% [markdown]
# ## 닉네임 별 데이터 수
# ***

# %%
game_all.groupby("USER").count().reset_index()[["USER","DATE"]].sort_values(by=["DATE"],ascending=False).head(10)
# Out:
#             USER  DATE
# 1039  hadigreece     3
# 2204          고농     3
# 2788       냉정평가맨     3
# 3586        마타도르     3
# 6231         전략맨     3
# 1361      qwarde     2
# 4023       발키리뮤즈     2
# 7264       하라니지라     2
# 6820          컷백     2
# 3724         면도오     2

# %%
# 같은 닉네임을 가지고 있으면 한 유저라고 가정
same_nickname=game_all.groupby("USER").count().reset_index()[["USER","DATE"]].sort_values(by=["DATE"],ascending=False)

# %%
str(round(len(same_nickname[same_nickname["DATE"]>1])/len(game_all)*100,2))+"%"
# Out:
# '1.72%'

# %%
same_nickname.head()
# Out:
#             USER  DATE
# 1039  hadigreece     3
# 2204          고농     3
# 2788       냉정평가맨     3
# 3586        마타도르     3
# 6231         전략맨     3

# %%
game_all[game_all["USER"]=="애옹 나 고양이"][["STAR","REVIEW","GAME"]]
# Out:
#       STAR                                             REVIEW    GAME
# 1253     3  3성떠도 픽업캐가 안나옴…뭐 가끔 운 정말 좋으면 픽업캐가 나오긴하지만 10번 뽑으...  블루아카이브
# 7558     1                        판 다 깔아줘도 운영 ㅈㄴ못함\n그냥 섭종해라ㅋㅋ   우마무스메

# %% [markdown]
# # 전체 글자 별 제목 비율
# ***

# %%
game_all["제목 차지비율"]=game_all["제목수"]/game_all["all_text_data_length"]*100

# %%
game_all["제목 차지비율"].describe()
# Out:
# count    7834.000000
# mean       24.835489
# std        20.100002
# min         0.196464
# 25%         9.090909
# 50%        18.604651
# 75%        35.714286
# max        98.484848
# Name: 제목 차지비율, dtype: float64

# %%
game_all_1000=game_all.sort_values(by=["all_text_data_length"],ascending=False).head(1000)
game_all_1000.STAR.mean()
# Out:
# 2.954

# %% [markdown]
# ## 게임 별 데이터 분석
# ***

# %%
game_all.GAME.value_counts()
# Out:
# 가디언테일즈      500
# 달빛조각사       500
# 블루아카이브      500
# 배틀그라운드      500
# 탕탕특공대       500
# 바람의나라연      500
# 검은사막        500
# 오딘발할라라이징    500
# 아키에이지워      500
# 미르          500
# 쿠키런킹덤       500
# 리니지m        500
# 리니지w        500
# 원신          500
# 우마무스메       500
# 프라시아전기      334
# Name: GAME, dtype: int64

# %%
#게임 별 평균 스타 수 확인
game_all_meanstar=game_all.groupby("GAME").mean().reset_index()[["GAME","STAR"]]

# %%
plt.figure(figsize=(20,8))
sns.barplot(x="GAME", y="STAR",data=game_all_meanstar)
# Out:
# <Axes: xlabel='GAME', ylabel='STAR'>

# %%
game_all_meanstar
# Out:
#         GAME      STAR
# 0     가디언테일즈  3.342000
# 1       검은사막  4.490000
# 2      달빛조각사  3.478000
# 3       리니지m  1.828000
# 4       리니지w  1.846000
# 5         미르  2.200000
# 6     바람의나라연  1.878000
# 7     배틀그라운드  2.750000
# 8     블루아카이브  3.358000
# 9     아키에이지워  3.462000
# 10  오딘발할라라이징  3.320000
# 11     우마무스메  2.014000
# 12        원신  4.248000
# 13     쿠키런킹덤  3.570000
# 14     탕탕특공대  3.518000
# 15    프라시아전기  2.721557

# %% [markdown]
# #워드클라우딩

# %%
pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.2)

# %%
# *- encoding: utf-8 -*- 패키지 불러오는 작업
import json
import ast
import sys
import re #정규 표현식 가지고 오는 패키지
from konlpy.tag import Twitter
from konlpy.tag import Komoran
from konlpy.tag import Kkma

# %%
# 토큰화 : 쪼개는거
# 태깅 : 명사 , 동사 구분해주는 것  ( 명사,동사 or 명사 형용사)
# 빈도
# 어린왕자 : 8 , 떡 : 10 ,
# 글씨크기가 달라지고 - > 워드 클라우드

# %%
game_all["ALL_TEXT"]=game_all["TITLE"]+game_all["REVIEW"]

# %%
game_data_text=game_all["ALL_TEXT"].tolist()

# %%
#tokenizer-> word 토큰화
#pos tagging okt
#pos tagging -> pos (품사), tagging(붙여주는 )
#stop word -> 불용어

ff=open('텍스트데이터.txt','w')

from konlpy.tag import Okt
okt=Okt() #함수 이름 새롭게 정의
documents1=[]


def tokenizer(raw, pos=["Noun"], stopword=["게임"]):
    return [
        word for word, tag in okt.pos( #okt.pos 태깅을 해서 word  사람 tag Adverb
            raw,
            norm=True,   # normalize 그랰ㅋㅋ -> 그래ㅋㅋ
            stem=True    # stemming 바뀌나->바뀌다
            )
            if len(word) > 1 and tag in pos and word not in stopword
        ]

documents1=tokenizer(str(game_data_text))
print(documents1)

for b in range(0,len(documents1)):
    fb=documents1[b]
    ff.write('%s \n'%fb)

ff.close()
# Out:
# ['초보', '고수', '화목', '한게임', '경쟁', '분위기', '길드', '고수', '운영', '갑자기', '다른', '그대로', '이번', '업뎃', '현상', '렉땜', '자꾸', '캐릭', '지금', '월드', '부활', '계속', '아이폰', '프로', '거울', '균열', '튕겨', '카마', '결과', '튕겨', '레이드', '튕겨', '스토리', '튕겨', '보스', '튕겨', '하라', '고요', '진짜', '리뷰', '한숨', '리뷰', '소액', '현질', '욀케', '스토리', '진짜', '굿겜', '문제점', '스코겜', '스토리', '난이도', '정도', '스토리', '진행', '진화', '노가다', '문제점', '확률', '쓰레기', '무기', '전용', '무기', '하나', '문제점', '크리스탈', '내용', '관련', '문제', '고치', '문제', '카카오', '쥐꼬리', '만큼', '저희', '과금', '유저', '유저', '차이', '마지막', '스토리', '시작', '스토리', '문제', '때문', '준비', '개발자', '제발', '문제', '해결', '닌텐도', '핸드폰', '다운', '리뷰', '진짜', '이번', '주말', '땜시', '주말', '도둑', '책임', '진짜', '섭종', '진짜', '섭종', '진짜', '지금', '추천', '사가', '스토리', '밀고', '테꿀잼', '집대성', '치뷰', '리뷰', '확률', '확정', '소환', '확률', '망겜', '데기', '다이아', '삽구', '데기', '와중', '친구', '몇개', '계정', '삭제', '박움', '진짜', '캐릭터', '개성', '스토리', '방식', '무엇', '부족함', '계속', '순간', '방치', '캐릭터', '베스', '때문', '무용지물', '무언', '압박', '진짜', '주말', '오전', '시작', '지금', '오후', '폰겜', '해도', '진짜', '콘솔', '그냥', '비판', '리뷰', '대부분', '공감', '서버', '유저', '로써', '가챠', '확률', '생각', '과금', '수위', '그닥', '그냥', '리뷰', '공감', '스토리', '때문', '플레이', '유저', '로써', '스토리', '밀면', '주기', '스토리', '업데이트', '리뷰', '과장', '사실', '지금', '엔딩', '엔딩', '수도', '시스템', '과금', '지금', '모험', '중반', '정도', '계정', '무기', '나름', '마음', '리세', '슬슬', '힐러', '검색', '복각', '복귀', '매출', '순위', '인기', '순위', '진짜', '역대', '시스템', '최적화', '사람', '장기', '정도', '스킵', '버튼', '그냥', '시나리오', '연출', '시나리오', '마다', '그냥', '개임', '삭제', '현상', '가디언', '테일즈', '정말', '플레이', '스테미', '재화', '뽑기', '확률', '다른', '다른', '스토리', '클리셰', '덩어리', '스토리', '문제', '문제', '그래픽', '처리', '효과', '처리', '효과', '계속', '기종은', '아이폰', '저장', '공간', '널널', '현상', '언제', '금방', '다시', '언제', '다시', '시작', '나머지', '리뷰', '때문', '월드', '스테이지', '진행', '도중', '다시', '시작', '만약', '수정', '문제', '라면', '수정', '외한', '한번', '부담', '진짜', '신경안', '마이', '페이스', '스토리', '크게', '스트레스', '캐릭', '빡세', '캐릭', '자체', '과금', '안해', '생각', '캐릭', '스토리', '계속', '표시', '보스', '시작', '계속', '롤백', '다시', '데이터', '무제한', '데이터', '서버', '생각', '계속', '서버', '개발', '사분', '서버', '운영', '그냥', '버그', '버근', '테미', '거득', '차단', '이유', '우편함', '운영', '선물', '손해', '렙업', '아이템', '등등', '화가', '버그', '버거', '스테미', '신분', '테미', '고민', '이신', '진행', '부유', '가디언', '포인트', '가디언', '레벨', '달성', '균열', '소탕', '그것', '캐릭터', '진화', '석도', '테미', '일석이조', '딴말', '안함', '진짜', '딴말', '안함', '스토리', '출시', '루즈', '분재', '바보', '한번', '양산', '포맷', '스테이지', '퍼즐', '형식', '흥미', '중독', '개쩜', '알파', '망겜', '아이폰', '플레이', '이제', '무시', '생각', '생각', '재미', '때문', '정신', '도중', '문제', '정원', '캐릭터', '스트레스', '진심', '개갓', '아이폰', '업데이트', '수록', '현상', '심해', '최근', '플레이', '영향', '주네', '조금', '다시', '자동', '모드', '자동', '전투', '버그', '수정', '월드', '상단', '부분', '보물상자', '이후', '다시', '시작', '상자', '버튼', '다시', '클리어', '상황', '다시', '가면', '시스템', '번은', '공주', '밧줄', '컴퓨터', '해킹', '미니게임', '부분', '미니게임', '한번', '클리어', '설정', '때문', '이후', '다시', '미니게임', '클리어', '도달', '다시', '필요', '다시', '시작', '수정', '아이패드', '플레이', '마리안', '스위치', '단계', '페북', '상단', '마리안', '스킵', '계속', '진행', '표시', '그대로', '효과음', '그냥', '진행', '당신', '정말', '선택', '당신', '정말', '생각', '스토리', '첨가', '미니게임', '정말', '다만', '난이도', '울타리', '당신', '클리어', '방해', '스피드', '대결', '부분', '정말', '부시', '난이도', '생각', '가지', '오리', '울타리', '그냥', '만약', '이글', '당신', '컨트롤', '능력', '해도', '상관', '다만', '컨트롤', '그냥', '재미', '로만', '진짜', '중학교', '지금', '직장인', '한번', '리뷰', '작성', '진짜', '겜생', '나머지', '컴겜', '모바일', '정도', '스토리', '컨텐츠', '모바일', '처음', '귯귯륫', '슛슛', '재미', '예전', '일상', '이제', '유저', '평균', '레벨', '레벨', '거의', '테미', '이상', '모이', '개발자', '주시', '점검', '보상', '선물', '그거', '때문', '모험', '크리스탈', '스테', '미나', '여기저기', '테미', '모험', '별로', '유저', '생각', '드네', '복귀', '유저', '보상', '일러스트', '스토리', '캐릭터', '별로', '정도', '스팩', '기도', '기도', '난이도', '정말', '추천', '인생게임', '인생게임', '원래', '진짜', '현질', '영웅', '컬렉션', '욕심', '처음', '현질', '과금', '스토리', '진짜', '개월', '지금', '가끔', '정도', '정말', '이후', '모바일', '최고', '임시', '뮬겜', '스타일', '거부', '모바일', '보기', '퀄리티', '모바일', '특유', '조잡', '요소', '다이아', '스토리', '거리', '다만', '스토리', '스킵', '부분', '성격', '살짝', '진행', '없겠죵', '순위', '시간', '비석', '미니맵', '표시', '다시', '하니', '어디', '인지도', '나중', '하니', '미니맵', '표시', '사랑', '재미', '진짜', '제대로', '추천', '캐릭터', '공격', '추천', '지루함', '진짜', '그대로', '지루함', '메인', '스토리', '진행', '외전', '시나리오', '서큐버스', '카페', '카페', '운영', '시스템', '보고 ...

# %%
# pos tagging, tag 종류 확인
# Adjective Noun Verb 주로 사용
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
import csv, sys
import numpy as np
# tf , tf-idf -> sklearn tf -> countVectorizer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

# %%
openFileName = '텍스트데이터.txt'

f = open(openFileName, 'r')
data = f.read()
f.close()

# %%
data = [data]
vectorize = CountVectorizer()
X = vectorize.fit_transform(data)

# %%
freqs = [(word, X.getcol(idx).sum()) for word, idx in vectorize.vocabulary_.items()]
dict(freqs)
# Out:
# {'초보': 25,
#  '고수': 8,
#  '화목': 1,
#  '한게임': 22,
#  '경쟁': 20,
#  '분위기': 7,
#  '길드': 32,
#  '운영': 427,
#  '갑자기': 152,
#  '다른': 194,
#  '그대로': 67,
#  '이번': 142,
#  '업뎃': 148,
#  '현상': 207,
#  '렉땜': 1,
#  '자꾸': 259,
#  '캐릭': 123,
#  '지금': 264,
#  '월드': 50,
#  '부활': 15,
#  '계속': 572,
#  '아이폰': 937,
#  '프로': 106,
#  '거울': 1,
#  '균열': 5,
#  '튕겨': 227,
#  '카마': 1,
#  '결과': 21,
#  '레이드': 24,
#  '스토리': 399,
#  '보스': 78,
#  '하라': 129,
#  '고요': 19,
#  '진짜': 762,
#  '리뷰': 244,
#  '한숨': 7,
#  '소액': 8,
#  '현질': 395,
#  '욀케': 1,
#  '굿겜': 5,
#  '문제점': 16,
#  '스코겜': 1,
#  '난이도': 60,
#  '정도': 281,
#  '진행': 185,
#  '진화': 9,
#  '노가다': 36,
#  '확률': 247,
#  '쓰레기': 156,
#  '무기': 83,
#  '전용': 6,
#  '하나': 296,
#  '크리스탈': 20,
#  '내용': 29,
#  '관련': 37,
#  '문제': 298,
#  '고치': 24,
#  '카카오': 162,
#  '쥐꼬리': 1,
#  '만큼': 8,
#  '저희': 12,
#  '과금': 613,
#  '유저': 906,
#  '차이': 39,
#  '마지막': 36,
#  '시작': 313,
#  '때문': 198,
#  '준비': 17,
#  '개발자': 106,
#  '제발': 400,
#  '해결': 217,
#  '닌텐도': 5,
#  '핸드폰': 78,
#  '다운': 146,
#  '주말': 7,
#  '땜시': 2,
#  '도둑': 7,
#  '책임': 7,
#  '섭종': 15,
#  '추천': 90,
#  '사가': 20,
#  '밀고': 8,
#  '테꿀잼': 1,
#  '집대성': 1,
#  '치뷰': 1,
#  '확정': 13,
#  '소환': 23,
#  '망겜': 112,
#  '데기': 4,
#  '다이아': 93,
#  '삽구': 1,
#  '와중': 10,
#  '친구': 103,
#  '몇개': 17,
#  '계정': 298,
#  '삭제': 195,
#  '박움': 1,
#  '캐릭터': 389,
#  '개성': 22,
#  '방식': 24,
#  '무엇': 47,
#  '부족함': 6,
#  '순간': 35,
#  '방치': 30,
#  '베스': 1,
#  '무용지물': 1,
#  '무언': 2,
#  '압박': 4,
#  '오전': 6,
#  '오후': 4,
#  '폰겜': 4,
#  '해도': 185,
#  '콘솔': 4,
#  '그냥': 466,
#  '비판': 6,
#  '대부분': 30,
#  '공감': 3,
#  '서버': 275,
#  '로써': 17,
#  '가챠': 59,
#  '생각': 377,
#  '수위': 4,
#  '그닥': 3,
#  '플레이': 326,
#  '밀면': 5,
#  '주기': 15,
#  '업데이트': 720,
#  '과장': 4,
#  '사실': 28,
#  '엔딩': 3,
#  '수도': 23,
#  '시스템': 118,
#  '모험': 28,
#  '중반': 2,
#  '나름': 47,
#  '마음': 79,
#  '리세': 21,
#  '슬슬': 8,
#  '힐러': 3,
#  '검색': 15,
#  '복각': 47,
#  '복귀': 88,
#  '매출': 12,
#  '순위': 9,
#  '인기': 18,
#  '역대': 30,
#  '최적화': 70,
#  '사람': 358,
#  '장기': 2,
#  '스킵': 37,
#  '버튼': 52,
#  '시나리오': 12,
#  '연출': 13,
#  '마다': 28,
#  '개임': 47,
#  '가디언': 26,
#  '테일즈': 18,
#  '정말': 335,
#  '스테미': 7,
#  '재화': 38,
#  '뽑기': 242,
#  '클리셰': 1,
#  '덩어리': 4,
#  '그래픽': 190,
#  '처리': 51,
#  '효과': 10,
#  '기종은': 17,
#  '저장': 47,
#  '공간': 45,
#  '널널': 3,
#  '언제': 119,
#  '금방': 17,
#  '다시': 507,
#  '나머지': 15,
#  '스테이지': 41,
#  '도중': 25,
#  '만약': 13,
#  '수정': 137,
#  '라면': 33,
#  '외한': 1,
#  '한번': 240,
#  '부담': 9,
#  '신경안': 3,
#  '마이': 3,
#  '페이스': 1,
#  '크게': 23,
#  '스트레스': 76,
#  '빡세': 8,
#  '자체': 128,
#  '안해': 49,
#  '표시': 18,
#  '롤백': 5,
#  '데이터': 54,
#  '무제한': 5,
#  '개발': 61,
#  '사분': 1,
#  '버그': 322,
#  '버근': 1,
#  '테미': 16,
#  '거득': 1,
#  '차단': 10,
#  '이유': 114,
#  '우편함': 11,
#  '선물': 20,
#  '손해': 6,
#  '렙업': 19,
#  '아이템': 181,
#  '등등': 36,
#  '화가': 40,
#  '버거': 1,
#  '신분': 13,
#  '고민': 18,
#  '이신': 1,
#  '부유': 1,
#  '포인트': 19,
#  '레벨': 142,
#  '달성': 4,
#  '소탕': 13,
#  '그것': 50,
#  '석도': 2,
#  '일석이조': 1,
#  '딴말': 2,
#  '안함': 32,
#  '출시': 83,
#  '루즈': 2,
#  '분재': 5,
#  '바보': 9,
#  '양산': 48,
#  '포맷': 2,
#  '퍼즐': 8,
#  '형식': 8,
#  '흥미': 22,
#  '중독': 39,
#  '개쩜': 2,
#  '알파': 1,
#  '이제': 171,
#  '무시': 29,
#  '재미': 268,
#  '정신': 27,
#  '정원': 1,
#  '진심': 49,
#  '개갓': 1,
#  '수록': 9,
#  '심해': 28,
#  '최근': 63,
#  '영향': 8,
#  '주네': 6,
#  '조금': 107,
#  '자동': 85,
#  '모드': 94,
#  '전투': 47,
#  '상단': 6,
#  '부분': 99,
#  '보물상자': 3,
#  '이후': 169,
#  '상자': 44,
#  '클리어': 31,
#  '상황': 38,
#  '가면': 38,
#  '번은': 16,
#  '공주': 8,
#  '밧줄': 1,
#  '컴퓨터': 24,
#  '해킹': 24,
#  '미니게임': 7,
#  '설정': 68,
#  '도달': 2,
#  '필요': 32,
#  '아이패드': 250,
#  '마리안': 3,
#  '스위치': 4,
#  '단계': 16,
#  '페북': 21,
#  '효과음': 4,
#  '당신': 28,
#  '선택': 109,
#  '첨가': 1,
#  '다만': 51,
#  '울타리': 2,
#  '방해': 4,
#  '스피드': 2,
#  '대결': 3,
#  '부시': 1,
#  '가지': 62,
#  '오리': 3,
#  '이글': 5,
#  '컨트롤': 13,
#  '능력': 19,
#  '상관': 5,
#  '로만': 25,
#  '중학교': 1,
#  '직장인': 9,
#  '작성': 14,
#  '겜생': 2,
#  '컴겜': 1,
#  '모바일': 209,
#  '컨텐츠': 146,
#  '처음': 259,
#  '귯귯륫': 1,
#  '슛슛': 1,
#  '예전': 77,
#  '일상': 6,
#  '평균': 5,
#  '거의': 61,
#  '이상': 135,
#  '모이': 1,
#  '주시': 23,
#  '점검': 91,
#  '보상': 190,
#  '그거': 45,
#  '스테': 3,
#  '미나': 2,
#  '여기저기': 6,
#  '별로': 45,
#  '드네': 15,
#  '일러스트': 23,
#  '스팩': 10,
#  '기도': 31,
#  '인생게임': 20,
#  '원래': 53,
#  '영웅': 43,
#  '컬렉션': 7,
#  '욕심': 10,
#  '개월': 32,
#  '가끔': 41,
#  '최고': 147,
#  '임시': 7,
#  '뮬겜': 1,
#  '스타일': 8,
#  '거부': 3,
#  '보기': 38,
#  '퀄리티': 51,
#  '특유': 3,
#  '조잡': 1,
#  '요소': 54,
#  '거리': 30,
#  '성격': 8,
#  '살짝': 15,
#  '없겠죵': 1,
#  '시간': 342,
#  '비석': 1,
#  '미니맵': 4,
#  '하니': 23,
#  '어디': 60,
#  '인지도': 5,
#  '나중': 23,
#  '사랑': 83,
#  '제대로': 102,
#  '공격': 45,
#  '지루함': 8,
#  '메인': 46,
#  '외전': 14,
#  '서큐버스': 4,
#  '카페': 26,
#  '보고': 126,
#  '심지어': 32,
#  '내부': 7,
#  '오락실': 1,
#  '승부': 1,
#  '자극': 6,
#  '미니': 56,
#  '경험치': 26,
#  '골드': 31,
#  '아야': 5,
#  '육성': 35,
#  '가성': 4,
#  '모든': 49,
#  '장단점': 1,
#  '즐겜': 11,
#  '강제': 32,
#  '종료': 48,
#  '콜라보': 25,
#  '발생': 65,
#  '확인': 110,
#  '새해': 3,
#  '첫날': 2,
#  '타이': 3,
#  '인내심': 9,
#  '공부': 6,
#  '스킬': 101,
#  '며칠': 23,
#  '구석구석': 1,
#  '보물찾기': 1,
#  '옛날': 53,
#  '감성': 20,
#  '달전': 1,
#  '신규': 57,
#  '매번': 41,
#  '넘사벽': 4,
#  '하루': 134,
#  '쥉일': 1,
#  '개굴잼': 1,
#  '프레임': 23,
#  '안정': 20,
#  '뭔가': 46,
#  '버벅': 4,
#  '뚝뚝': 2,
#  '사양': 21,
#  '저번': 25,
#  '패치': 176,
#  '버벅거림': 3,
#  '대체': 32,
#  '건가': 92,
#  '이해': 63,
#  '안감': 4,
#  '스튜디오': 5,
#  '마카롱': 1,
#  '유도': 169,
#  '남캐': 7,
#  '삼위일체': 1,
#  '일주일': 48,
#  '콜로세움': 4,
#  '아레나': 45,
#  '무과': 46,
#  '금도': 30,
#  '번창': 5,
#  '저승': 7,
#  '주식회사': 7,
#  '결전': 4,
#  '아고라': 9,
#  '증거': 10,
#  '제출': 5,
#  '판정': 9,
#  '영상': 21,
#  '도대체': 55,
#  '극악': 24,
#  '느낌': 79,
#  '잘만': 29,
#  '테러': 8,
#  '대신': 16,
#  '바로': 96,
#  '부실': 6,
#  '토리': 7,
#  '이외': 3,
#  '수단': 3,
#  '거만': 7,
#  '개선': 165,
#  '밸런스': 44,
#  '순삭': 5,
#  '짜임새': 3,
#  '추가': 92,
#  '투자': 37,
#  '절대': 58,
#  '무슨': 148,
#  '오히려': 13,
#  '답임': 2,
#  '굿굿': 85,
#  '점도': 26,
#  '라이트닝': 2,
#  '카운터': 4,
#  '여캐': 7,
#  '매력': 25,
#  '노력': 30,
#  '보이': 17,
#  '뭐함': 6,
#  '설명': 24,
#  '김현': 70,
#  '자주': 92,
#  '편이': 11,
#  '동안': 61,
#  '상이': 24,
#  '정상': 43,
#  '불가': 64,
#  '튕김떼문': 1,
#  '떼문': 1,
#  '상태': 45,
#  '적도': 10,
#  '실력': 18,
#  '요즘': 91,
#  '이안': 11,
#  '중간': 72,
#  '포기': 25,
#  '얼마': 43,
#  '코스튬': 7,
#  '광고': 278,
#  '우리': 28,
#  '환영': 2,
#  '조정': 18,
#  '어쩌': 22,
#  '은지': 7,
#  '린지': 6,
#  '아예': 117,
#  '한계': 10,
#  '지경': 8,
#  '구형': 3,
#  '튕기': 249,
#  '튕겨야': 4,
#  '어찌': 19,
#  '어나더': 1,
#  '콩스': 6,
#  '잘못': 53,
#  '해처': 3,
#  '사용': 117,
#  '안지우': 1,
#  '커피': 7,
#  '확장': 7,
#  '부탁': 44,
#  '스태미나': 7,
#  '최대': 21,
#  '불편': 11,
#  '우편': 4,
#  '저기': 6,
#  '튕겨져': 4,
#  '실행': 242,
#  '도트': 3,
#  '정착': 7,
#  '완료': 26,
#  '매니아': 1,
#  '여기': 42,
#  '렵니': 2,
#  '작동': 13,
#  '하나요': 44,
#  '플랫폼': 3,
#  '오류': 281,
#  '어캐좀': 1,
#  '기사': 6,
#  '상점': 37,
#  '패키지': 88,
#  '지급': 24,
#  '일시': 4,
#  '복구': 68,
#  '버전': 86,
#  '질문': 9,
#  '전부': 43,
#  '메뉴': 14,
#  '퀘스트': 119,
#  '전체': 18,
#  '항목': 3,
#  '보통': 10,
#  '인터넷': 18,
#  '히든': 9,
#  '인지': 17,
#  '해당': 13,
#  '정보': 23,
#  '공홈': 2,
#  '부득이': 1,
#  '답변': 80,
#  '설치': 153,
#  '나용': 1,
#  '이벤트': 253,
#  '보석': 51,
#  '무조건': 39,
#  '주식': 18,
#  '폭망': 3,
#  '회사': 97,
#  '독창': 2,
#  '거기': 31,
#  '여타': 5,
#  '로그인': 179,
#  '문의': 88,
#  '아앙': 2,
#  '생기': 19,
#  '접속': 697,
#  '다운로드': 108,
#  '실패': 26,
#  '파도': 1,
#  '빵빵': 7,
#  '삭함': 1,
#  '티어': 43,
#  '부술듯': 1,
#  '환불': 184,
#  '꿀잼': 53,
#  '보장': 6,
#  '일리': 3,
#  '광대': 16,
#  '사건': 10,
#  '친추': 2,
#  '기능': 78,
#  '오픈': 82,
#  '주년': 25,
#  '한마디': 19,
#  '소모': 14,
#  '무한': 46,
#  '반복': 73,
#  '노잼': 39,
#  '최종': 10,
#  '스펙': 22,
#  '길레': 3,
#  '딜딸뿐': 1,
#  '점점': 70,
#  '퍼즐게임': 1,
#  '도박': 94,
#  '남녀': 4,
#  '노소': 1,
#  '누구': 18,
#  '상원': 5,
#  '이형': 5,
#  '화이팅': 36,
#  '뚜뚜뚜앗': 1,
#  '뎃데로게데뎃': 1,
#  '몰입': 10,
#  '다음': 58,
#  '만듬': 10,
#  '거르': 9,
#  '카겜': 19,
#  '저승사자': 1,
#  '제시': 3,
#  '혹시': 64,
#  '정답': 2,
#  '랜덤': 15,
#  '마라도': 2,
#  '평생': 10,
#  '관심': 18,
#  '자마자': 18,
#  '초창': 15,
#  '잠깐': 31,
#  '점핑': 1,
#  '사고': 15,
#  '스레': 2,
#  '을소': 1,
#  '중복': 20,
#  '공개': 1,
#  '상승': 3,
#  '노말': 1,
#  '불가능': 9,
#  '최신': 31,
#  '지역': 14,
#  '기반': 8,
#  '디자인': 31,
#  '런칭때': 1,
#  '인생': 72,
#  '디테일': 10,
#  '정성': 6,
#  '완전': 63,
#  '진입': 15,
#  '장벽': 10,
#  '그림': 14,
#  '인물': 22,
#  '피지': 2,
#  '아공': 1,
#  '공쥬': 1,
#  '간다': 16,
#  '현실': 15,
#  '조작': 48,
#  '정채': 1,
#  '일부': 14,
#  '출석': 20,
#  '체크': 5,
#  '강화': 43,
#  '반년': 4,
#  '사항': 19,
#  '한참': 11,
#  '고려': 8,
#  '지점': 2,
#  '그동안': 11,
#  '반영': 15,
#  '튜토리얼': 11,
#  '처럼': 37,
#  '신경': 36,
#  '검토': 12,
#  '캐시': 10,
#  '부디': 6,
#  '위해': 41,
#  '젤다': 19,
#  '버스': 9,
#  '한지': 35,
#  '마법': 18,
#  '학교': 4,
#  '갈고리': 1,
#  '라운드': 27,
#  '손님': 3,
#  '리스트': 5,
#  '유경': 1,
#  '명작': 17,
#  '직원': 22,
#  '기믹': 6,
#  '장르': 9,
#  '허용': 5,
#  '또한': 27,
#  '포함': 6,
#  '아동': 2,
#  '성매매': 1,
#  '암시': 1,
#  '추후': 4,
#  '안내': 13,
#  '컴백': 1,
#  '거임': 17,
#  '아아': 9,
#  '데스': 21,
#  '매치': 28,
#  '루피': 1,
#  '휘저으': 1,
#  '다양성': 1,
#  '차라리': 28,
#  '중점': 1,
#  '기적': 12,
#  '누가': 34,
#  '겜임': 17,
#  '심중': 1,
#  '꼭좀': 2,
#  '테츠': 2,
#  '마고': 2,
#  '악몽': 2,
#  '이여진': 1,
#  '국산': 14,
#  '가장': 49,
#  '수준': 57,
#  '우리나라': 16,
#  '매뉴얼': 1,
#  '개도': 37,
#  '그게': 28,
#  '불만': 16,
#  '이면': 34,
#  '수익': 8,
#  '조합': 23,
#  '레트로': 1,
#  '전혀': 55,
#  '이나': 15,
#  '퍼줘': 4,
#  '전편': 2,
#  '세심': 3,
#  '완성': 13,
#  '도도': 1,
#  '한가지': 18,
#  '이야기': 21,
#  '현재': 56,
#  '시즌': 24,
#  '제작': 32,
#  '화협': 1,
#  '동전': 4,
#  '끼리': 14,
#  '친목': 2,
#  '유물': 11,
#  '인물화': 1,
#  '혜자': 17,
#  '사정': 2,
#  '초과': 8,
#  '그때': 26,
#  '흥분': 1,
#  '유니크': 3,
#  '지장': 11,
#  '티탄': 2,
#  '왕국': 31,
#  '개껌': 2,
#  '나무': 9,
#  '보이지': 9,
#  '패러디': 4,
#  '오지': 26,
#  '참고': 46,
#  '여대생': 1,
#  '취향': 11,
#  '저격': 7,
#  '성인': 5,
#  '해주': 16,
#  '진성': 1,
#  '최악': 101,
#  '모습': 28,
#  '보임': 17,
#  '후반': 9,
#  '뗘야함': 1,
#  '근대': 3,
#  '부로': 4,
#  '갈수록': 28,
#  '어쩌구': 5,
#  '솔직': 7,
#  '일지': 3,
#  '미래': 16,
#  '전환': 5,
#  '요청': 50,
#  '영구': 14,
#  '정지': 70,
#  '장문': 2,
#  '극찬': 2,
#  '고이': 3,
#  '자사': 18,
#  '존잼': 20,
#  '남캐좀': 4,
#  '중원': 1,
#  '마는': 3,
#  '제일': 43,
#  '디테': 9,
#  '일이': 22,
#  '애니': 5,
#  '기획': 13,
#  '모두': 33,
#  '흥해랏': 2,
#  '제국': 3,
#  '몇번': 81,
#  '리소스': 30,
#  '튕고': 1,
#  '던전': 38,
#  '두번째': 10,
#  '남쪽': 1,
#  '애기': 3,
#  '장애물': 1,
#  '애초': 21,
#  '파서': 4,
#  '대감': 2,
#  '가득': 6,
#  '관계자': 7,
#  '조절': 17,
#  '구간': 9,
#  '파이팅': 5,
#  '주작인': 1,
#  '픽뚫': 16,
#  '재밌넹': 2,
#  '그다음': 4,
#  '솔로': 8,
#  '연인': 2,
#  '맵때': 1,
#  '뭐시기': 4,
#  '튕김': 229,
#  '여자': 6,
#  '캐좀': 1,
#  '자캐': 1,
#  '씹덕': 9,
#  '비율': 10,
#  '덕겜': 2,
#  '바스': 1,
#  '모핑': 1,
#  '남자': 4,
#  '타겟': 5,
#  '가요': 114,
#  '유아': 1,
#  '젖꼭지': 1,
#  '심의': 4,
#  '통과': 1,
#  '초반': 63,
#  '숫자': 12,
#  '주마': 8,
#  '이상은': 10,
#  '의리': 1,
#  '승하': 3,
#  '에스': 3,
#  '제밋': 1,
#  '픽셀': 2,
#  '부족': 13,
#  '개잼': 5,
#  '체고': 2,
#  '고액': 3,
#  '사료': 9,
#  '장점': 28,
#  '작년': 12,
#  '여름': 3,
#  '아주': 85,
#  '사이': 11,
#  '발전': 22,
#  '가데': 1,
#  '무재': 3,
#  '소비': 8,
#  '소지': 2,
#  '알람': 6,
#  '단기간': 1,
#  '구조': 9,
#  '방법': 90,
#  '지목': 2,
#  '특능': 1,
#  '통채': 2,
#  '픽업': 31,
#  '사기': 23,
#  '가치': 18,
#  '유지': 20,
#  '머리': 30,
#  '낭비': 10,
#  '최애': 6,
#  '원툴': 2,
#  '띵작': 2,
#  '건데': 3,
#  '컷나': 1,
#  '마법사': 4,
#  '단번': 1,
#  '풀피': 2,
#  '사제': 1,
#  '소린': 2,
#  '소신': 2,
#  '발언': 5,
#  '툴겜': 1,
#  '속성': 3,
#  '역속': 1,
#  '배치': 20,
#  '정체': 2,
#  '매일': 51,
#  '추억': 56,
#  '분명': 17,
#  '초기': 93,
#  '생활비': 1,
#  '물류': 1,
#  '센터': 48,
#  '일용직': 1,
#  '마냥': 21,
#  '루비': 1,
#  '개입': 7,
#  '터치': 74,
#  '수가': 40,
#  '지금껏': 3,
#  '미세먼지': 1,
#  '수련': 2,
#  '달리기': 1,
#  '경주': 1,
#  '라이': 26,
#  '짜증': 21,
#  '패널': 1,
#  '건너': 1,
#  '해주시': 34,
#  '아마': 9,
#  '만하': 35,
#  '시장': 13,
#  '줄기': 4,
#  '오아시스': 2,
#  '표현': 7,
#  '종사': 1,
#  '여러분': 27,
#  '고생': 20,
#  '변경': 41,
#  '뭉뭉': 1,
#  '버프좀': 3,
#  '세상': 20,
#  '옶어': 1,
#  '얼른': 18,
#  '유유': 1,
#  '티닝': 1,
#  '소녀': 9,
#  '씨발': 15,
#  '간담': 36,
#  '겜돔황챠': 1,
#  '하자': 29,
#  '라잌어중학생딬': 1,
#  '뽀뽀': 1,
#  '개돼지': 65,
#  '퍼블리셔': 15,
#  '기분': 37,
#  '화악': 1,
#  '김상원': 2,
#  '디렉터': 10,
#  '말씀': 9,
#  '희망이': 4,
#  '회로': 4,
#  '오늘': 144,
#  '약속': 9,
#  '지기': 2,
#  '유튜버': 2,
#  '논란': 7,
#  '자신': 16,
#  '색깔': 2,
#  '전이': 7,
#  '운전': 1,
#  '초드': 1,
#  '학년': 1,
#  '학생': 27,
#  '정이': 15,
#  '도끼': 1,
#  '에러': 35,
#  '달라': 29,
#  '고고': 1,
#  '뺑뺑': 2,
#  '수집': 14,
#  '구분': 2,
#  '지표': 1,
#  '지갑': 12,
#  '앱스토어': 32,
#  '검열': 19,
#  '액션': 5,
#  '손맛': 1,
#  '물리': 2,
#  '제외': 7,
#  '주인공': 2,
#  '피망': 1,
#  '데몬': 2,
#  '슬레이어즈': 1,
#  '헌금': 1,
#  '마무리': 4,
#  '크리스털': 2,
#  '연속': 23,
#  '장비': 102,
#  '반전': 2,
#  '애바임': 1,
#  '인베이더': 1,
#  '체력': 11,
#  '간만': 19,
#  '굿굿굿': 17,
#  '장난': 70,
#  '임무': 22,
#  '악당': 2,
#  '시선': 4,
#  '나가시': 1,
#  '태일': 1,
#  '제한': 30,
#  '대박': 23,
#  '레전드': 15,
#  '기록': 16,
#  '카톡': 11,
#  '일단': 80,
#  '앞길': 1,
#  '세계': 17,
#  '통로': 3,
#  '년전': 8,
#  '러시': 2,
#  '히히히': 2,
#  '세라': 3,
#  '케릭': 70,
#  '피해': 20,
#  '파티원': 6,
#  '적의': 3,
#  '피하': 3,
#  '지도': 12,
#  '지뢰': 1,
#  '경우': 67,
#  '여유': 11,
#  '전략': 4,
#  '의심': 11,
#  ...}

# %%
from wordcloud import WordCloud

w=WordCloud(font_path='/content/drive/MyDrive/bytedegree/BMDOHYEON_ttf.ttf', width=800,height=600,mode='RGBA',background_color='white',max_words=1000).fit_words(dict(freqs))

import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(w)
#plt.axis(&quot;off&quot;)

plt.show()

# %%
# 긍부정 -> 워드클라우드
# 게임 별 -> 워드클라우드
# 리뷰수가 많은 애들 -> 워드클라우드
# 명사 -> 형용사 , 동사 바꿔나가면서 유저 파악
# TFIDF / COUNT VECTORIZER 가 다른것들을 파악
